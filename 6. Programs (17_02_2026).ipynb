# %% [markdown]
# <a href="https://colab.research.google.com/github/Saturn-space/Saturn-space/blob/Python/6.%20Programs%20(17_02_2026).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. program to varify single digit exist in a list if more than single exits add them and print the new list.

number = [22,4,53,87,34,2]

def sum(arg):
  new_number = []

  for i in arg:
      if(i>=10 and i<=99):
        value = 0;
        while i!=0:
          value += i%10
        new_number.append(value)

      else:
        new_number.append(i)

  return new_number

new_number = []
for i in number:
      if(i>=10 and i<=99):
        value = 0;
        while i!=0:
          value += i%10
          i = i//10;
        new_number.append(value)
      else:
        new_number.append(i)

print(new_number)
# Out:
# [4, 4, 8, 15, 7, 2]

# %%
#2. Program to add items along with some details and find the total payable amount.

stock = {}

def items():
  n = int(input("Enter the number of items :  "))

  for i in range(n):
    id = int(input("Enter the Product ID : "))
    name = input("Enter the Product Name : ")
    price = int(input("Enter the Product Price : "))
    Qty = int(input("Enter the Product Quntity : "))
    Brand = input("Enter the Product Brand : ")

    stock[id] = [name,price,Qty,Brand]

  print(stock)

def total():
  sum = 0
  for i in stock.values():
    sum += i[1]*i[2]

  print(f"Total Payable Amount : ${sum}")

items()
total()
# Out:
# Enter the number of items :  2
# Enter the Product ID : 1001
# Enter the Product Name : Apple Ipad
# Enter the Product Price : 69999
# Enter the Product Quntity : 1
# Enter the Product Brand : Apple
# Enter the Product ID : 1002
# Enter the Product Name : Samsung S240 Ultra
# Enter the Product Price : 79000
# Enter the Product Quntity : 1
# Enter the Product Brand : Samsung
# {1001: ['Apple Ipad', 69999, 1, 'Apple'], 1002: ['Samsung S240 Ultra', 79000, 1, 'Samsung']}
# Total Payable Amount : $148999

# %%
stock = {
    1001: ['Apple Ipad', 69999, 1, 'Apple'],
    1002: ['Samsung S240 Ultra', 79000, 1, 'Samsung'],
    1003: ['Pringles Salt-Cream', 2, 1, 'Pringles']
}

def items():
  n = int(input("Enter the Product ID of items :  "))

  for i in stock:
    if (i==n):
      price = int(input("Enter the prince :"))
      print(stock[i])

    else:
      print("Product ID not Found")

  print(stock)
  items()
